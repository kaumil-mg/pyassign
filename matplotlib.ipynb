# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.
#
#
# Matplotlib is a plotting library for the Python programming language that provides a variety of tools for creating visualizations, such as line charts, scatter plots, bar charts, and histograms. It is widely used in data science and scientific research to create informative and visually appealing graphs.
#
# Pyplot is a sublibrary of Matplotlib that provides a simple interface for creating and customizing plots. Some of the common plots that can be plotted using Pyplot module are:
#
# - Line plot
# - Scatter plot
# - Bar plot
# - Histogram plot
# - Pie plot

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.
#
# A scatter plot is a graph that shows the relationship between two continuous variables. It displays the values of two variables as a collection of points on a two-dimensional plane. Scatter plots are useful to determine whether there is a relationship between two variables or not.

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

plt.scatter(x, y)
plt.title('Scatter Plot')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
#
# The subplot() function is used to create multiple plots in a single figure. It takes three arguments: the number of rows, the number of columns, and the plot number.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the first plot
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])

# Data for the second plot
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

# Data for the third plot
x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

# Data for the fourth plot
x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

# Creating the subplot
fig, axs = plt.subplots(2, 2, figsize=(10, 8))
fig.suptitle('Multiple line plots')

# Plotting the first line
axs[0, 0].plot(x1, y1)
axs[0, 0].set_title('Line 1')
axs[0, 0].set_xlabel('X label')
axs[0, 0].set_ylabel('Y label')

# Plotting the second line
axs[0, 1].plot(x2, y2)
axs[0, 1].set_title('Line 2')
axs[0, 1].set_xlabel('X label')
axs[0, 1].set_ylabel('Y label')

# Plotting the third line
axs[1, 0].plot(x3, y3)
axs[1, 0].set_title('Line 3')
axs[1, 0].set_xlabel('X label')
axs[1, 0].set_ylabel('Y label')

# Plotting the fourth line
axs[1, 1].plot(x4, y4)
axs[1, 1].set_title('Line 4')
axs[1, 1].set_xlabel('X label')
axs[1, 1].set
# Out:
# <bound method _make_class_factory.<locals>.class_factory.<locals>.subcls.set of <AxesSubplot: title={'center': 'Line 4'}, xlabel='X label'>>

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
#
# A bar plot is a plot that represents data using rectangular bars. It is used to show comparisons between different categories of data

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# Bar plot
plt.bar(company, profit)
plt.title("Profit by Company")
plt.xlabel("Company")
plt.ylabel("Profit")
plt.show()

# Horizontal bar plot
plt.barh(company, profit)
plt.title("Profit by Company")
plt.xlabel("Profit")
plt.ylabel("Company")
plt.show()

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
#
# A box plot is a graphical representation of data distribution using five number summary method: minimum, first quartile, median, third quartile, and maximum. It helps in identifying the outliers in the data, and provides a visual way of comparing the distribution of multiple datasets.

# %%
import matplotlib.pyplot as plt
import numpy as np

box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

data = [box1, box2]
fig, ax = plt.subplots()

# creating the boxplot
ax.boxplot(data)

# setting labels
ax.set_xticklabels(['Box 1', 'Box 2'])
ax.set_ylabel('Values')

plt.title('Box Plot')

plt.show()
